# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %matplotlib inline

# %%
df = pd.read_csv('turnstile_may26.txt')

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6625470
# 1  REGULAR  6625494
# 2  REGULAR  6625514
# 3  REGULAR  6625595
# 4  REGULAR  6625791
#
#    EXITS
# 0                                            2245312
# 1                                            2245314
# 2                                            2245338
# 3                                            2245415
# 4                                            2245481

# %%
df['TIME'] = pd.to_datetime(df['TIME'])

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198174 entries, 0 to 198173
# Data columns (total 11 columns):
# C/A                                                                     198174 non-null object
# UNIT                                                                    198174 non-null object
# SCP                                                                     198174 non-null object
# STATION                                                                 198174 non-null object
# LINENAME                                                                198174 non-null object
# DIVISION                                                                198174 non-null object
# DATE                                                                    198174 non-null datetime64[ns]
# TIME                                                                    198174 non-null datetime64[ns]
# DESC                                                                    198174 non-null object
# ENTRIES                                                                 198174 non-null int64
# EXITS                                                                   198174 non-null int64
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 16.6+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
#
#                  TIME     DESC  ENTRIES  \
# 0 2018-09-25 00:00:00  REGULAR  6625470
# 1 2018-09-25 04:00:00  REGULAR  6625494
# 2 2018-09-25 08:00:00  REGULAR  6625514
# 3 2018-09-25 12:00:00  REGULAR  6625595
# 4 2018-09-25 16:00:00  REGULAR  6625791
#
#    EXITS
# 0                                            2245312
# 1                                            2245314
# 2                                            2245338
# 3                                            2245415
# 4                                            2245481

# %%
len(df['STATION'].unique())
# Out:
# 375

# %%
maps_api = ''

# %%
import googlemaps

# %%
gmaps = googlemaps.Client(key=maps_api)

# %%
stations = df['STATION'].unique()

# %%
ny_stations = list(map(lambda x: x + ', New York, NY', stations))

# %%
from collections import defaultdict

# %%
unique_geocodes = defaultdict(str)

# %%
for address in ny_stations:
    geocode = gmaps.geocode(address)
    unique_geocodes[address] = geocode

# %%
len(unique_geocodes)
# Out:
# 375

# %%
# results[0].address_components
# address[address.length - 1].long_name;

# %%
unique_geocodes[7][0]['address_components'][6]['short_name']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-62a88c90bc20> in <module>()
# ----> 1 unique_geocodes[7][0]['address_components'][6]['short_name']
#
# IndexError: list index out of range

# %%
for address in ny_stations:
    print(unique_geocodes[address])
# Out:
#   File "<ipython-input-30-3cbe3739b258>", line 2
#     print unique_geocodes[address]
#                         ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(unique_geocodes[address])?

# %%
zipcodes = []

for geocode in unique_geocodes:
    try:
        print(geocode)
        print('Successfully found zip data')
        address = geocode[0]['address_components']
        if address[len(address) - 1]['types'] == ['postal_code']:
            zipcodes.append(address[len(address)- 1]['long_name'])
    except:
        print('No zip data')
# Out:
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# No zip data

# %%
zipcodes
# Out:
# []

# %%
len(zipcodes)
# Out:
# 168

# %%
test_add = gmaps.geocode('59 ST, New York, NY')

# %%
json_str = json.dumps(test_add)

# %%
json_zip = json.loads(json_str)

# %%
json_zip[0]['address_components'][6]['short_name']
# Out:
# '10022'

# %% [markdown]
# ## Income data

# %%
# !ls
# Out:
# 16zpallagi.csv        benson-KF.ipynb       benson_zipcodes.ipynb
# KFtest.txt            benson.ipynb          turnstile_may26.txt

# %%
inc = pd.read_csv('16zpallagi.csv')

# %%
inc.columns
# Out:
# Index(['STATEFIPS', 'STATE', 'zipcode', 'agi_stub', 'N1', 'mars1', 'MARS2',
#        'MARS4', 'PREP', 'N2',
#        ...
#        'N10300', 'A10300', 'N85530', 'A85530', 'N85300', 'A85300', 'N11901',
#        'A11901', 'N11902', 'A11902'],
#       dtype='object', length=147)
