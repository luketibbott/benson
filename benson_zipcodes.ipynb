# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %matplotlib inline

# %%
df = pd.read_csv('turnstile_may26.txt')

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/19/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6625470
# 1  REGULAR  6625494
# 2  REGULAR  6625514
# 3  REGULAR  6625595
# 4  REGULAR  6625791
#
#    EXITS
# 0                                            2245312
# 1                                            2245314
# 2                                            2245338
# 3                                            2245415
# 4                                            2245481

# %%
df['TIME'] = pd.to_datetime(df['TIME'])

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198174 entries, 0 to 198173
# Data columns (total 11 columns):
# C/A                                                                     198174 non-null object
# UNIT                                                                    198174 non-null object
# SCP                                                                     198174 non-null object
# STATION                                                                 198174 non-null object
# LINENAME                                                                198174 non-null object
# DIVISION                                                                198174 non-null object
# DATE                                                                    198174 non-null datetime64[ns]
# TIME                                                                    198174 non-null datetime64[ns]
# DESC                                                                    198174 non-null object
# ENTRIES                                                                 198174 non-null int64
# EXITS                                                                   198174 non-null int64
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 16.6+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-05-19
#
#                  TIME     DESC  ENTRIES  \
# 0 2018-09-25 00:00:00  REGULAR  6625470
# 1 2018-09-25 04:00:00  REGULAR  6625494
# 2 2018-09-25 08:00:00  REGULAR  6625514
# 3 2018-09-25 12:00:00  REGULAR  6625595
# 4 2018-09-25 16:00:00  REGULAR  6625791
#
#    EXITS
# 0                                            2245312
# 1                                            2245314
# 2                                            2245338
# 3                                            2245415
# 4                                            2245481

# %%
len(df['STATION'].unique())
# Out:
# 375

# %%
maps_api = 'AIzaSyCnU97Og25CRFm90i5Eru5rqKrTgHx07IY'

# %%
import googlemaps

# %%
gmaps = googlemaps.Client(key=maps_api)

# %%
stations = df['STATION'].unique()

# %%
ny_stations = list(map(lambda x: x + ', New York, NY', stations))

# %%
from collections import defaultdict

# %%
unique_geocodes = defaultdict(str)

# %%
for address in ny_stations:
    geocode = gmaps.geocode(address)
    unique_geocodes[]

# %%
len(unique_geocodes)
# Out:
# 375

# %%
unique_geocodes[13]
# Out:
# [{'address_components': [{'long_name': 'Cortlandt Street',
#     'short_name': 'Cortlandt St',
#     'types': ['route']},
#    {'long_name': 'Manhattan',
#     'short_name': 'Manhattan',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'New York',
#     'short_name': 'New York',
#     'types': ['locality', 'political']},
#    {'long_name': 'New York County',
#     'short_name': 'New York County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '10007', 'short_name': '10007', 'types': ['postal_code']}],
#   'formatted_address': 'Cortlandt St, New York, NY 10007, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 40.7103917,
#      'lng': -74.00997500000001},
#     'southwest': {'lat': 40.7098106, 'lng': -74.0112145}},
#    'location': {'lat': 40.7103778, 'lng': -74.0112104},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 40.7114501302915,
#      'lng': -74.0092457697085},
#     'southwest': {'lat': 40.7087521697085, 'lng': -74.0119437302915}}},
#   'place_id': 'ChIJnZ2P3BlawokR_hTPVpz7hIQ',
#   'types': ['route']}]

# %%
# results[0].address_components
# address[address.length - 1].long_name;

# %%
unique_geocodes[7][0]['address_components'][6]['short_name']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-62a88c90bc20> in <module>()
# ----> 1 unique_geocodes[7][0]['address_components'][6]['short_name']
#
# IndexError: list index out of range

# %%
zipcodes = []

for geocode in unique_geocodes:
    try:
        print('Successfully found zip data')
        address = geocode[0]['address_components']
        if address[len(address) - 1]['types'] == ['postal_code']:
            zipcodes.append(address[len(address)- 1]['long_name'])
    except:
        print('No zip data')
# Out:
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# No zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data
# Successfully found zip data

# %%
zipcodes
# Out:
# ['10022',
#  '10022',
#  '10106',
#  '10018',
#  '10001',
#  '10001',
#  '10003',
#  '10003',
#  '10007',
#  '10007',
#  '10006',
#  '10004',
#  '10002',
#  '10007',
#  '10007',
#  '11225',
#  '11225',
#  '11226',
#  '11229',
#  '11201',
#  '11201',
#  '11217',
#  '11215',
#  '10016',
#  '10036',
#  '10019',
#  '11209',
#  '11219',
#  '10021',
#  '10075',
#  '11214',
#  '11224',
#  '10002',
#  '11237',
#  '10029',
#  '11435',
#  '11385',
#  '11207',
#  '11208',
#  '11421',
#  '10025',
#  '10027',
#  '10036',
#  '10034',
#  '10040',
#  '10033',
#  '10033',
#  '10027',
#  '10029',
#  '10025',
#  '10024',
#  '10036',
#  '10120',
#  '10012',
#  '11201',
#  '10016',
#  '11238',
#  '11213',
#  '11233',
#  '11208',
#  '11208',
#  '11208',
#  '10024',
#  '10019',
#  '11417',
#  '11693',
#  '11694',
#  '11694',
#  '11693',
#  '11692',
#  '11692',
#  '11691',
#  '11691',
#  '10451',
#  '10453',
#  '10453',
#  '10467',
#  '10022',
#  '10010',
#  '11101',
#  '11101',
#  '10036',
#  '10065',
#  '11373',
#  '11375',
#  '11375',
#  '11432',
#  '11101',
#  '11206',
#  '11205',
#  '10020',
#  '10018',
#  '10012',
#  '10013',
#  '11231',
#  '11215',
#  '11215',
#  '11234',
#  '10010',
#  '10044',
#  '11101',
#  '11418',
#  '11435',
#  '10021',
#  '10028',
#  '10128',
#  '10464',
#  '11211',
#  '10014',
#  '07310',
#  '10002',
#  '07114',
#  '10007',
#  '10006',
#  '10004',
#  '10013',
#  '10003',
#  '10027',
#  '10031',
#  '10032',
#  '10040',
#  '10034',
#  '10034',
#  '10009',
#  '10004',
#  '10038',
#  '10003',
#  '10017',
#  '10021',
#  '10451',
#  '10451',
#  '10453',
#  '10033',
#  '10470',
#  '10026',
#  '10039',
#  '10455',
#  '11101',
#  '10459',
#  '10459',
#  '11222',
#  '10460',
#  '11413',
#  '10454',
#  '10454',
#  '10454',
#  '10459',
#  '10462',
#  '10461',
#  '10461',
#  '11101',
#  '11101',
#  '11101',
#  '11101',
#  '11101',
#  '11104',
#  '11104',
#  '11377',
#  '11372',
#  '11373',
#  '11368',
#  '11368',
#  '10001',
#  '11201',
#  '11225',
#  '11415',
#  '11210',
#  '10301']

# %%
len(zipcodes)
# Out:
# 168

# %%
test_add = gmaps.geocode('59 ST, New York, NY')

# %%
json_str = json.dumps(test_add)

# %%
json_zip = json.loads(json_str)

# %%
json_zip[0]['address_components'][6]['short_name']
# Out:
# '10022'
